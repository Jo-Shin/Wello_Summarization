# %% [markdown]
# # 노가다 이후 임베딩
# - **환경설정**은 경로를 설정하는 chunk(cd/.....)까지 돌려주세요.
# - 그 이후론 맨 마지막 파트인 **'환경설정 후 이것만 돌려주세요!'** 만 실행해주시면 됩니다!

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 993 kB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.6 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 76.2 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %% [markdown]
# # 환경설정

# %%
import pandas as pd
import json
import random
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import torch
import re
import os
#from konlpy.tag import Okt
import konlpy

from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.simplefilter("ignore")

from gensim.models import word2vec
from gensim.models import Word2Vec

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 원하는 경로 설정
cd /content/drive/Shareddrives/DSL_2021_2_웰로/(최종)웰로 전달 C팀
# Out:
# /content/drive/Shareddrives/DSL_2021_2_웰로/(최종)웰로 전달 C팀

# %% [markdown]
# # 데이터 정의

# %%
df = pd.read_excel('./data/policy_metatable.xlsx') #8만개

# %%
df.index = df.정책ID

# %%
title = df.서비스명
purpose = df.서비스목적
content = df.지원내용
subject = df.지원대상

# %% [markdown]
# # 텍스트 전처리

# %% [markdown]
# ## 사용자 사전 생성
# - 지원대상과 관련된 여러 키워드들을 사용자 사전에 등록

# %% [markdown]
# ### 태그 검색 키워드 추가

# %%
tag_meta = pd.read_excel('./data/tag_meta_subject_final.xlsx')

# %%
tag_meta.head()
# Out:
#         칼럼      카테고리                                              찾는 단어
# 0  태그-대상특성       장애인                                             장애인,장애
# 1  태그-대상특성     농축수산인  농축수산,농업,농민,농촌,농가,농지,작물,재배,원예특용,어업,양식업,농지소유자,지주...
# 2  태그-대상특성  질병,부상,질환  질병,부상,질환,환자,요양,치매,입원,결핵,아토피,천식,에이즈,성병,AIDS,암환자...
# 3  태그-대상특성        난임                                              난임,불임
# 4  태그-대상특성       임신부                           임신부,임부,출산전,출산예정,예비부모,임신중

# %%
userdic = []

for Words in tag_meta.카테고리:
  for word in Words.split(','):
    userdic.append(word.strip())

for Words in tag_meta['찾는 단어']:
  for word in Words.split(','):
    userdic.append(word.strip())

userdic = sorted(list(set(userdic)))

# %%
userdic
# Out:
# ['1인가구',
#  '2자녀',
#  '30인미만',
#  '3자녀',
#  '4자녀',
#  '50인미만',
#  '518민주유공자',
#  '5자녀',
#  'AIDS',
#  '가축',
#  '결핵',
#  '결혼장려',
#  '경관농업',
#  '경관농업인',
#  '경관작물',
#  '경로당',
#  '경종농가',
#  '경종농업',
#  '경종농업인',
#  '경증장애',
#  '고기잡이배',
#  '고깃배',
#  '고엽제',
#  '과수농업',
#  '과수농업인',
#  '구인',
#  '구직',
#  '구직자',
#  '구직활동',
#  '구획어업',
#  '국가유공자',
#  '근로복지',
#  '근로자',
#  '근로지원',
#  '근해어업',
#  '기관',
#  '기업',
#  '기초생활',
#  '기초생활수급자',
#  '기타농업',
#  '기타농업인',
#  '기타어업',
#  '기타어업인',
#  '난임',
#  '난치성질환',
#  '난치질환',
#  '난치질환자',
#  '남성',
#  '농가',
#  '농민',
#  '농업',
#  '농지',
#  '농지소유자',
#  '농촌',
#  '농축수산',
#  '농축수산인',
#  '다둥이',
#  '다문화',
#  '다문화가정',
#  '다문화가족',
#  '다자녀',
#  '다자녀가구',
#  '다자녀가정',
#  '단체',
#  '대학',
#  '대학교',
#  '대학생',
#  '대학원생',
#  '독거노인',
#  '독립유공자',
#  '동아리',
#  '모자보건수첩',
#  '민간업',
#  '민주유공자',
#  '벌채',
#  '법인',
#  '보육',
#  '보육시설',
#  '보훈가족',
#  '보훈대상자',
#  '부상',
#  '부상자',
#  '북한이탈주민',
#  '불임',
#  '사회복지법인',
#  '사회적기업',
#  '산모',
#  '산후조리원',
#  '성병',
#  '센터',
#  '소사육',
#  '소상공인',
#  '소상인',
#  '수급자',
#  '수유부',
#  '시설',
#  '식물재배',
#  '신생아',
#  '실업자',
#  '심하지않은장애',
#  '심한장애',
#  '아토피',
#  '알선',
#  '암환자',
#  '양식업',
#  '양식업인',
#  '양육수당',
#  '어린이집',
#  '어선소유',
#  '어선소유자',
#  '어선을',
#  '어업',
#  '어촌',
#  '에이즈',
#  '여성',
#  '연근해구획어업인',
#  '연근해어업',
#  '연안어업',
#  '예비부모',
#  '예비창업자',
#  '외국인',
#  '요양',
#  '요양환자',
#  '원예작물',
#  '원예특용',
#  '원예특용농업인',
#  '원예특용작물',
#  '위안부',
#  '유공',
#  '유산',
#  '유치사업',
#  '유치원',
#  '육아',
#  '육아용품',
#  '육아지원',
#  '이산가족',
#  '일자리',
#  '임부',
#  '임산부',
#  '임신',
#  '임신부',
#  '임신중',
#  '임업',
#  '임업인',
#  '입양',
#  '입양가정',
#  '입양가족',
#  '입양아',
#  '입원',
#  '자영업자',
#  '작물',
#  '작업장',
#  '장애',
#  '장애인',
#  '재배',
#  '재외국민',
#  '재외국인',
#  '저소득',
#  '전역군인',
#  '제대군인',
#  '조산',
#  '조손',
#  '조손가정',
#  '조손가족',
#  '중소기업',
#  '중증장애',
#  '중증질환',
#  '중증질환자',
#  '지주',
#  '직장인',
#  '진로',
#  '질병',
#  '질환',
#  '질환자',
#  '차상위',
#  '차상위계층',
#  '참전군인',
#  '참전용사',
#  '참전유공자',
#  '창업',
#  '창업 아이템',
#  '창업교육',
#  '창업자',
#  '창업자금지원',
#  '창업지원',
#  '천식',
#  '축산농가',
#  '축산물',
#  '축산업',
#  '축산업인',
#  '출산',
#  '출산가정',
#  '출산양육',
#  '출산예정',
#  '출산전',
#  '출산지원',
#  '출산진료',
#  '출산축하',
#  '출산후',
#  '출생신고',
#  '치매',
#  '치매환자',
#  '탈북',
#  '탈북자',
#  '태아',
#  '특수임무유공자',
#  '특수형태근로',
#  '특용작물',
#  '프리랜서',
#  '학교',
#  '학자금',
#  '한부모',
#  '한부모가정',
#  '한부모가족',
#  '한센인',
#  '환자',
#  '희귀난치성질환',
#  '희귀질환',
#  '희귀질환자']

# %% [markdown]
# ### 노가다 결과 추가

# %%
# sentence_raw='근로 자녀 장려금 근로자 녀 장려 세제 저소득 계층 빈곤 탈출 지원 사회 안전망 확..'
# word = '근로자녀'

# for i in range(len(word)):
#   fix_word = word[:i] + ' ' + word[i:]
#   if fix_word in sentence_raw:
#     sentence_new = re.sub(fix_word,word,sentence_raw) # pattern, replace, subject
#     print(sentence_new)

# %%
# worksheet = gc.open('noun_unique_final').sheet1
# rows = worksheet.get_all_values()

# %%
# more_user_df = pd.DataFrame.from_records(rows[1:], columns = rows[0])
# more_user = more_user_df['추가할 단어'].unique().tolist()

# %%
# more_user.remove('')

# %%
# more_user_lst = []

# for Words in more_user:
#   for word in Words.split(','):
#     more_user_lst.append(word.strip())

# %%
# more_user_lst = list(set(more_user_lst))

# %%
# temp = pd.DataFrame(more_user_lst)
# temp.to_csv('./data/사용자 사전 후보_노가다.csv', index=False, encoding='CP949')

# %%
more_userdic = pd.read_csv('./data/more_userdic.csv',encoding='CP949').word.tolist()

# %%
more_userdic[:5]
# Out:
# ['고속도로통행료', '전통시장', '독서문화프로그램', '의료보호혜택', '독립유공']

# %% [markdown]
# ### 모든 단어 병합 및 사전 형성

# %%
final_userdic = list(set(userdic + more_userdic))

# %%
# final_userdic

# %%
# 코모란에 넣을 사용자사전을 txt 파일로 변경

with open('./data/userdict.txt','w') as f:
  for word in final_userdic:
    f.write(word+'\tNNG\n')

# %% [markdown]
# ## 품사 태깅

# %%
komoran = konlpy.tag.Komoran(userdic='./data/userdict.txt')

# %%
# 정상적으로 사용자 사전을 인식하는지 테스트
temp = ' '.join(final_userdic)
test = komoran.pos(temp)
test
# Out:
# [('민주유공자', 'NNG'),
#  ('다문화가족지원센터', 'NNG'),
#  ('꿈나무', 'NNG'),
#  ('소귀표', 'NNG'),
#  ('농지소유자', 'NNG'),
#  ('버스정류장', 'NNG'),
#  ('출생신고', 'NNG'),
#  ('보호시설', 'NNG'),
#  ('중독관리', 'NNG'),
#  ('자살예방', 'NNG'),
#  ('미아방지', 'NNG'),
#  ('건강벼', 'NNG'),
#  ('기회부족', 'NNG'),
#  ('재능기부', 'NNG'),
#  ('종량제 봉투', 'NNG'),
#  ('행정서비스', 'NNG'),
#  ('방위협의회', 'NNG'),
#  ('무료진료', 'NNG'),
#  ('종사자', 'NNG'),
#  ('전세자금', 'NNG'),
#  ('재산처분', 'NNG'),
#  ('중증질환', 'NNG'),
#  ('결식어르신', 'NNG'),
#  ('창업보육센터', 'NNG'),
#  ('청년인턴', 'NNG'),
#  ('교재비', 'NNG'),
#  ('선취업', 'NNG'),
#  ('무료셔틀버스', 'NNG'),
#  ('정서적', 'NNG'),
#  ('저소득국민', 'NNG'),
#  ('기타농업', 'NNG'),
#  ('정착지원', 'NNG'),
#  ('노인세대', 'NNG'),
#  ('자동계좌이체', 'NNG'),
#  ('문화예술공간', 'NNG'),
#  ('민관', 'NNG'),
#  ('전용주차', 'NNG'),
#  ('직업훈련비', 'NNG'),
#  ('위안부할머니', 'NNG'),
#  ('임대지원', 'NNG'),
#  ('방사성페기물', 'NNG'),
#  ('녹색도시', 'NNG'),
#  ('수수료', 'NNG'),
#  ('차량', 'NNG'),
#  ('방문상담', 'NNG'),
#  ('생애주기별', 'NNG'),
#  ('예절교실', 'NNG'),
#  ('센터운영지원', 'NNG'),
#  ('일반실', 'NNG'),
#  ('직장체험', 'NNG'),
#  ('일손부족', 'NNG'),
#  ('여성안심택배서비스', 'NNG'),
#  ('요양환자', 'NNG'),
#  ('문화체험비', 'NNG'),
#  ('위생업소', 'NNG'),
#  ('안심폰', 'NNG'),
#  ('유아보육', 'NNG'),
#  ('여성친화도시', 'NNG'),
#  ('청년실업', 'NNG'),
#  ('주거지원금', 'NNG'),
#  ('생태관광', 'NNG'),
#  ('전문교육', 'NNG'),
#  ('전월세', 'NNG'),
#  ('인권', 'NNG'),
#  ('산후관리', 'NNG'),
#  ('에너지절감', 'NNG'),
#  ('의료급여법', 'NNG'),
#  ('독서교실', 'NNG'),
#  ('정신건강복지센터', 'NNG'),
#  ('청각장애', 'NNG'),
#  ('수도요금', 'NNG'),
#  ('손해금', 'NNG'),
#  ('마사지교실', 'NNG'),
#  ('녹색성장', 'NNG'),
#  ('암벽장', 'NNG'),
#  ('매입비', 'NNG'),
#  ('해양중소벤처기업', 'NNG'),
#  ('사회적 약자', 'NNG'),
#  ('아동양육시설', 'NNG'),
#  ('영양플러스서비스', 'NNG'),
#  ('독립운동가', 'NNG'),
#  ('장애정도심한장애인', 'NNG'),
#  ('자동차운수사업', 'NNG'),
#  ('조건불리지역', 'NNG'),
#  ('저해요인', 'NNG'),
#  ('마이스터', 'NNG'),
#  ('물가안정', 'NNG'),
#  ('맞춤형', 'NNG'),
#  ('기초생활수급자', 'NNG'),
#  ('연수지원', 'NNG'),
#  ('무료이동지원서비스', 'NNG'),
#  ('수혜금', 'NNG'),
#  ('교통안내', 'NNG'),
#  ('장애인차량', 'NNG'),
#  ('발달재활서비스', 'NNG'),
#  ('평생교육진흥', 'NNG'),
#  ('치매상담센터', 'NNG'),
#  ('미혼남녀', 'NNG'),
#  ('직불금', 'NNG'),
#  ('충전소', 'NNG'),
#  ('특급', 'NNG'),
#  ('의료보호혜택', 'NNG'),
#  ('검진비', 'NNG'),
#  ('영세운송사업자', 'NNG'),
#  ('해난', 'NNG'),
#  ('성과보상', 'NNG'),
#  ('정신의료기관', 'NNG'),
#  ('자기관리', 'NNG'),
#  ('자연생태체험', 'NNG'),
#  ('지역특색', 'NNG'),
#  ('우편배송', 'NNG'),
#  ('열사용', 'NNG'),
#  ('동물용', 'NNG'),
#  ('시각장애인', 'NNG'),
#  ('공동브랜드', 'NNG'),
#  ('해양사고', 'NNG'),
#  ('긴급복지대상자', 'NNG'),
#  ('도농상생장', 'NNG'),
#  ('재활치료', 'NNG'),
#  ('확산방지', 'NNG'),
#  ('순천만국가정원', 'NNG'),
#  ('등록', 'NNG'),
#  ('모바일웹', 'NNG'),
#  ('숲해설', 'NNG'),
#  ('낙농업', 'NNG'),
#  ('경종농업', 'NNG'),
#  ('공공시설', 'NNG'),
#  ('무선인터넷', 'NNG'),
#  ('축산업', 'NNG'),
#  ('곤충사육시설', 'NNG'),
#  ('일자리센터', 'NNG'),
#  ('사용료', 'NNG'),
#  ('로컬푸드', 'NNG'),
#  ('국가지정문화재', 'NNG'),
#  ('부착유생', 'NNG'),
#  ('엽산지원', 'NNG'),
#  ('멘티', 'NNG'),
#  ('납부약', 'NNG'),
#  ('어선을', 'NNG'),
#  ('물품수령', 'NNG'),
#  ('민원업무', 'NNG'),
#  ('소변검사', 'NNG'),
#  ('해양플랜트', 'NNG'),
#  ('족구장', 'NNG'),
#  ('미소지자', 'NNG'),
#  ('대체교사', 'NNG'),
#  ('공익광고', 'NNG'),
#  ('돌보미', 'NNG'),
#  ('지연배상금', 'NNG'),
#  ('학습시설', 'NNG'),
#  ('체험교실', 'NNG'),
#  ('낙농농가', 'NNG'),
#  ('복지서비스', 'NNG'),
#  ('만성정신질환자', 'NNG'),
#  ('중소기업', 'NNG'),
#  ('아동보호치료시설', 'NNG'),
#  ('사회복지시설', 'NNG'),
#  ('건강음료', 'NNG'),
#  ('에너지절약', 'NNG'),
#  ('탁아방', 'NNG'),
#  ('장애아가족', 'NNG'),
#  ('경제발전', 'NNG'),
#  ('자금', 'NNG'),
#  ('스포츠강좌', 'NNG'),
#  ('조산', 'NNG'),
#  ('디아크', 'NNG'),
#  ('장애부모', 'NNG'),
#  ('택시운송사업', 'NNG'),
#  ('도체', 'NNG'),
#  ('교육프로그램', 'NNG'),
#  ('직전지불금', 'NNG'),
#  ('하절기', 'NNG'),
#  ('국가유공자', 'NNG'),
#  ('노인의날', 'NNG'),
#  ('국민안전처', 'NNG'),
#  ('공용시설물', 'NNG'),
#  ('진료비', 'NNG'),
#  ('출산장려금', 'NNG'),
#  ('임업인', 'NNG'),
#  ('취학전아동', 'NNG'),
#  ('운전면허증', 'NNG'),
#  ('공동생활가정', 'NNG'),
#  ('미적용', 'NNG'),
#  ('용달', 'NNG'),
#  ('의상자', 'NNG'),
#  ('공공부조기금', 'NNG'),
#  ('노후하우스시설', 'NNG'),
#  ('공립어린이집', 'NNG'),
#  ('위안부', 'NNG'),
#  ('온', 'NNG'),
#  ('소상공인', 'NNG'),
#  ('비정규직노동자', 'NNG'),
#  ('재활훈련', 'NNG'),
#  ('보육인프라', 'NNG'),
#  ('사업보조금', 'NNG'),
#  ('강서구립', 'NNG'),
#  ('정보공개', 'NNG'),
#  ('어린이회관', 'NNG'),
#  ('해외박람회', 'NNG'),
#  ('보험급여', 'NNG'),
#  ('동구청장', 'NNG'),
#  ('재난관리', 'NNG'),
#  ('장난감월드', 'NNG'),
#  ('노인의료복지', 'NNG'),
#  ('커리어넷', 'NNG'),
#  ('지불금', 'NNG'),
#  ('세트장', 'NNG'),
#  ('농지', 'NNG'),
#  ('재활프로그램', 'NNG'),
#  ('재난관리기금', 'NNG'),
#  ('개인위생', 'NNG'),
#  ('방제비', 'NNG'),
#  ('문화활동지원', 'NNG'),
#  ('기저귀대', 'NNG'),
#  ('통합서비스', 'NNG'),
#  ('고속도로통행료', 'NNG'),
#  ('난임여성', 'NNG'),
#  ('하나로패스', 'NNG'),
#  ('적성검사', 'NNG'),
#  ('자아성장', 'NNG'),
#  ('해양', 'NNG'),
#  ('숲유치원', 'NNG'),
#  ('농어업', 'NNG'),
#  ('화재피해', 'NNG'),
#  ('장기', 'NNG'),
#  ('재가급여', 'NNG'),
#  ('명품마을', 'NNG'),
#  ('가스터빈', 'NNG'),
#  ('학위', 'NNG'),
#  ('체납액', 'NNG'),
#  ('다둥이', 'NNG'),
#  ('농가소득', 'NNG'),
#  ('사회적기업', 'NNG'),
#  ('사회적배려자', 'NNG'),
#  ('무료경로식당', 'NNG'),
#  ('구직', 'NNG'),
#  ('요양급여', 'NNG'),
#  ('과태료부과', 'NNG'),
#  ('국적취득자', 'NNG'),
#  ('대행소', 'NNG'),
#  ('장례식장', 'NNG'),
#  ('기초생활보장법', 'NNG'),
#  ('기타농업인', 'NNG'),
#  ('어업안전', 'NNG'),
#  ('자원봉사단체', 'NNG'),
#  ('해산비', 'NNG'),
#  ('보호안전시설', 'NNG'),
#  ('국제인증', 'NNG'),
#  ('시민아카데미', 'NNG'),
#  ('치료재활센터', 'NNG'),
#  ('빗물이용시설', 'NNG'),
#  ('산학연계', 'NNG'),
#  ('중증난치성질환자', 'NNG'),
#  ('정보', 'NNG'),
#  ('자살예방센터', 'NNG'),
#  ('노인활동보조기구', 'NNG'),
#  ('과수농가', 'NNG'),
#  ('생활급여', 'NNG'),
#  ('안검진', 'NNG'),
#  ('법률서비스', 'NNG'),
#  ('과수생산', 'NNG'),
#  ('취업서비스', 'NNG'),
#  ('농촌지도자', 'NNG'),
#  ('노인복지시설', 'NNG'),
#  ('배송', 'NNG'),
#  ('치매조기검진', 'NNG'),
#  ('건강유지', 'NNG'),
#  ('방범설치', 'NNG'),
#  ('청소년시설', 'NNG'),
#  ('축하금', 'NNG'),
#  ('노인보호구역', 'NNG'),
#  ('풍수해보험료', 'NNG'),
#  ('노인대학', 'NNG'),
#  ('운수사업', 'NNG'),
#  ('성실납세자', 'NNG'),
#  ('저바이패스비', 'NNG'),
#  ('교구비', 'NNG'),
#  ('위문금', 'NNG'),
#  ('브랜드쌀', 'NNG'),
#  ('농가대출금', 'NNG'),
#  ('여성기업', 'NNG'),
#  ('미취학', 'NNG'),
#  ('취업상담원', 'NNG'),
#  ('신문구독료', 'NNG'),
#  ('농림수산식품부', 'NNG'),
#  ('운항사', 'NNG'),
#  ('희망통장', 'NNG'),
#  ('고엽제', 'NNG'),
#  ('교통공원', 'NNG'),
#  ('혹한기', 'NNG'),
#  ('소비습관', 'NNG'),
#  ('예비창업자', 'NNG'),
#  ('노인여가시설', 'NNG'),
#  ('건강관리사', 'NNG'),
#  ('장애통합보육시설', 'NNG'),
#  ('동아리', 'NNG'),
#  ('출산준비', 'NNG'),
#  ('가축사육', 'NNG'),
#  ('청년단체', 'NNG'),
#  ('진상파악', 'NNG'),
#  ('국제박람회', 'NNG'),
#  ('미취업', 'NNG'),
#  ('문화복지', 'NNG'),
#  ('결혼이민여성', 'NNG'),
#  ('축하용품', 'NNG'),
#  ('가금농장', 'NNG'),
#  ('장애인활동지원서비스', 'NNG'),
#  ('철분', 'NNG'),
#  ('야외상설무대', 'NNG'),
#  ('장애인도우미', 'NNG'),
#  ('체육대회', 'NNG'),
#  ('여가시설', 'NNG'),
#  ('아이돌봄센터', 'NNG'),
#  ('이민자일자리', 'NNG'),
#  ('무료급식사업', 'NNG'),
#  ('음식물류폐기물', 'NNG'),
#  ('모유수유클리닉', 'NNG'),
#  ('행정복지센터', 'NNG'),
#  ('가축재해보험', 'NNG'),
#  ('지역암센터', 'NNG'),
#  ('사회문제', 'NNG'),
#  ('다자녀', 'NNG'),
#  ('처리비', 'NNG'),
#  ('지방세', 'NNG'),
#  ('의료급여수급자', 'NNG'),
#  ('다목적하우스', 'NNG'),
#  ('구강보건', 'NNG'),
#  ('교통약자', 'NNG'),
#  ('개인특성맞춤복지서비스', 'NNG'),
#  ('감염인', 'NNG'),
#  ('작업훈련', 'NNG'),
#  ('수산식품', 'NNG'),
#  ('눈시야', 'NNG'),
#  ('취업희망자', 'NNG'),
#  ('해산급여', 'NNG'),
#  ('청각장애인', 'NNG'),
#  ('언어발달지원', 'NNG'),
#  ('신분노출', 'NNG'),
#  ('주거안정', 'NNG'),
#  ('고용창출장려금', 'NNG'),
#  ('심신발달', 'NNG'),
#  ('특수건강진단', 'NNG'),
#  ('소기업', 'NNG'),
#  ('다중이용시설', 'NNG'),
#  ('일반건강검진', 'NNG'),
#  ('경로환자', 'NNG'),
#  ('입양아동양육비', 'NNG'),
#  ('급식지원', 'NNG'),
#  ('캠핑장', 'NNG'),
#  ('학습의욕', 'NNG'),
#  ('어린이날', 'NNG'),
#  ('청년일자리', 'NNG'),
#  ('운영비', 'NNG'),
#  ('급식소', 'NNG'),
#  ('청소년공부방', 'NNG'),
#  ('회생자금', 'NNG'),
#  ('간판정비', 'NNG'),
#  ('경증장애', 'NNG'),
#  ('꿈다락', 'NNG'),
#  ('다대포', 'NNG'),
#  ('디도스', 'NNG'),
#  ('장학기금', 'NNG'),
#  ('무인항공기', 'NNG'),
#  ('영아반교사', 'NNG'),
#  ('선납', 'NNG'),
#  ('국가우수장학금', 'NNG'),
#  ('민주화운동', 'NNG'),
#  ('개인주택', 'NNG'),
#  ('안심귀가', 'NNG'),
#  ('환경프로그램', 'NNG'),
#  ('식물재배', 'NNG'),
#  ('종합검진서비스', 'NNG'),
#  ('옥외광고물', 'NNG'),
#  ('지식재산센터', 'NNG'),
#  ('수급가구', 'NNG'),
#  ('운전면허취득지원', 'NNG'),
#  ('공공임대', 'NNG'),
#  ('격리치료비', 'NNG'),
#  ('무료진료서비스', 'NNG'),
#  ('신장장애인', 'NNG'),
#  ('탈북', 'NNG'),
#  ('지식재산교육', 'NNG'),
#  ('운전지원', 'NNG'),
#  ('재가장애인', 'NNG'),
#  ('치매예방', 'NNG'),
#  ('치매검사비', 'NNG'),
#  ('재활서비스', 'NNG'),
#  ('쓰레기종량제봉투', 'NNG'),
#  ('경관농업', 'NNG'),
#  ('노인부양가정', 'NNG'),
#  ('승용차요일제', 'NNG'),
#  ('균등교육', 'NNG'),
#  ('화장장려금', 'NNG'),
#  ('건강검진서비스', 'NNG'),
#  ('주거교육급여수급자', 'NNG'),
#  ('포항시민', 'NNG'),
#  ('요양비', 'NNG'),
#  ('건강지킴이', 'NNG'),
#  ('예방관리', 'NNG'),
#  ('가난대물림', 'NNG'),
#  ('병해충', 'NNG'),
#  ('유스센터', 'NNG'),
#  ('고척돔', 'NNG'),
#  ('재난대응', 'NNG'),
#  ('사유재산', 'NNG'),
#  ('재난안전관리기본법', 'NNG'),
#  ('아동복지시설', 'NNG'),
#  ('불법', 'NNG'),
#  ('체험행사', 'NNG'),
#  ('한마당', 'NNG'),
#  ('기타어업', 'NNG'),
#  ('후원물품', 'NNG'),
#  ('담보', 'NNG'),
#  ('새마을운동', 'NNG'),
#  ('연금', 'NNG'),
#  ('교육지원', 'NNG'),
#  ('방사성', 'NNG'),
#  ('수출', 'NNG'),
#  ('장학재단', 'NNG'),
#  ('부설주차장', 'NNG'),
#  ('모범노동자', 'NNG'),
#  ('우수봉사자', 'NNG'),
#  ('가정양육비', 'NNG'),
#  ('요금할인', 'NNG'),
#  ('석면피해자', 'NNG'),
#  ('역사기록물', 'NNG'),
#  ('부산형', 'NNG'),
#  ('모자보건수첩', 'NNG'),
#  ('임산부', 'NNG'),
#  ('자율봉사단', 'NNG'),
#  ('한 부모 가정', 'NNG'),
#  ('비료지원', 'NNG'),
#  ('대학원생', 'NNG'),
#  ('영달', 'NNG'),
#  ('여가문화', 'NNG'),
#  ('불소', 'NNG'),
#  ('환경조성', 'NNG'),
#  ('출산예정', 'NNG'),
#  ('노후슬레이트처리비', 'NNG'),
#  ('강화섬쌀', 'NNG'),
#  ('보육도우미', 'NNG'),
#  ('치매안심센터', 'NNG'),
#  ('예비모', 'NNG'),
#  ('지방공기업', 'NNG'),
#  ('장려수당', 'NNG'),
#  ('민원후견인제', 'NNG'),
#  ('살처분', 'NNG'),
#  ('노인복지관', 'NNG'),
#  ('따복하우스', 'NNG'),
#  ('청년저축계좌', 'NNG'),
#  ('건강진단', 'NNG'),
#  ('난치성질환자', 'NNG'),
#  ('생신축하', 'NNG'),
#  ('선천대사', 'NNG'),
#  ('자활근로지원', 'NNG'),
#  ('기초생활', 'NNG'),
#  ('실내수영장', 'NNG'),
#  ('농산업체', 'NNG'),
#  ('연근해구획어업인', 'NNG'),
#  ('여가프로그램', 'NNG'),
#  ('지역사회서비스', 'NNG'),
#  ('커뮤니티센터', 'NNG'),
#  ('구직활동', 'NNG'),
#  ('청소년보호법', 'NNG'),
#  ('하수처리장', 'NNG'),
#  ('발효시설', 'NNG'),
#  ('정착비', 'NNG'),
#  ('노숙인자활', 'NNG'),
#  ('아동청소년', 'NNG'),
#  ('공동인증서', 'NNG'),
#  ('생계구호비', 'NNG'),
#  ('사회일원', 'NNG'),
#  ('어촌체험마을', 'NNG'),
#  ('만성폐쇄성폐질환', 'NNG'),
#  ('효장려', 'NNG'),
#  ('공경', 'NNG'),
#  ('특화분야', 'NNG'),
#  ('주거형태', 'NNG'),
#  ('이러닝', 'NNG'),
#  ('보건의료서비스', 'NNG'),
#  ('역사문화탐방', 'NNG'),
#  ('여성가족원', 'NNG'),
#  ('문화누리카드', 'NNG'),
#  ('사회복지단체', 'NNG'),
#  ('법률지원', 'NNG'),
#  ('장애인동반자', 'NNG'),
#  ('재난복구지원금', 'NNG'),
#  ('인라인스케이트', 'NNG'),
#  ('장기요양기관', 'NNG'),
#  ('노인폐렴구균', 'NNG'),
#  ('점자도서관', 'NNG'),
#  ('청소년산모', 'NNG'),
#  ('고교신입생', 'NNG'),
#  ('노원구민', 'NNG'),
#  ('청소년수련시설', 'NNG'),
#  ('사물인터넷', 'NNG'),
#  ('입양가정', 'NNG'),
#  ('전기요금', 'NNG'),
#  ('해외자원봉사', 'NNG'),
#  ('노인종합복지관', 'NNG'),
#  ('자립금', 'NNG'),
#  ('식품기부', 'NNG'),
#  ('중개업소', 'NNG'),
#  ('첨단기술', 'NNG'),
#  ('사체운반', 'NNG'),
#  ('서포터', 'NNG'),
#  ('규모재배농가', 'NNG'),
#  ('휴면', 'NNG'),
#  ('돌봄사업', 'NNG'),
#  ('상수원관리', 'NNG'),
#  ('사망자후견인', 'NNG'),
#  ('멘토', 'NNG'),
#  ('설치의무', 'NNG'),
#  ('온실가스', 'NNG'),
#  ('우체국쇼핑', 'NNG'),
#  ('빈집정비', 'NNG'),
#  ('공공도서', 'NNG'),
#  ('대구시청도서관', 'NNG'),
#  ('네트워킹', 'NNG'),
#  ('방문교육', 'NNG'),
#  ('여유공간', 'NNG'),
#  ('산학연', 'NNG'),
#  ('사회조사통계조사원', 'NNG'),
#  ('봉양지원', 'NNG'),
#  ('위험임산부', 'NNG'),
#  ('시민', 'NNG'),
#  ('입원격리', 'NNG'),
#  ('분쟁조정위원회', 'NNG'),
#  ('재외동포', 'NNG'),
#  ('양곡할인', 'NNG'),
#  ('학자금대출', 'NNG'),
#  ('생활안정지원', 'NNG'),
#  ('복지재단', 'NNG'),
#  ('과오급', 'NNG'),
#  ('문학글', 'NNG'),
#  ('독립유공묘지관리비', 'NNG'),
#  ('유기동물', 'NNG'),
#  ('하수처리', 'NNG'),
#  ('경영자금', 'NNG'),
#  ('보육시설', 'NNG'),
#  ('국민건강', 'NNG'),
#  ('산업자금', 'NNG'),
#  ('직장생활', 'NNG'),
#  ('국민기초생활보장법', 'NNG'),
#  ('종합재활서비스', 'NNG'),
#  ('임신중', 'NNG'),
#  ('지역사회적응', 'NNG'),
#  ('대출이자', 'NNG'),
#  ('소아암환자', 'NNG'),
#  ('응시수수료', 'NNG'),
#  ('누수요금', 'NNG'),
#  ('임신출산정보', 'NNG'),
#  ('노인복지', 'NNG'),
#  ('근로복지', 'NNG'),
#  ('문해어르신', 'NNG'),
#  ('쿼드검사', 'NNG'),
#  ('재향군인', 'NNG'),
#  ('건강지원', 'NNG'),
#  ('우수납세자', 'NNG'),
#  ('위로지원금', 'NNG'),
#  ('흑돼지', 'NNG'),
#  ('거주시설', 'NNG'),
#  ('장애인의날', 'NNG'),
#  ('테라피', 'NNG'),
#  ('군장병', 'NNG'),
#  ('결핵환자', 'NNG'),
#  ('생활습관개선', 'NNG'),
#  ('농업', 'NNG'),
#  ('상품권지급', 'NNG'),
#  ('평생교육', 'NNG'),
#  ('읍면', 'NNG'),
#  ('사회복귀', 'NNG'),
#  ('임신초기검사', 'NNG'),
#  ('외식업체', 'NNG'),
#  ('경기도', 'NNG'),
#  ('효행장려수당', 'NNG'),
#  ('실내공기질', 'NNG'),
#  ('입양축하금', 'NNG'),
#  ('학자금지원', 'NNG'),
#  ('아동보호전문기관', 'NNG'),
#  ('대학입학금', 'NNG'),
#  ('간병비', 'NNG'),
#  ('농산물가공지원센터', 'NNG'),
#  ('안전의식', 'NNG'),
#  ('질병예방', 'NNG'),
#  ('인공암벽장', 'NNG'),
#  ('재생에너지', 'NNG'),
#  ('꿀벌산업', 'NNG'),
#  ('의료기기산업', 'NNG'),
#  ('보전금', 'NNG'),
#  ('자활근로사업', 'NNG'),
#  ('의료비지원', 'NNG'),
#  ('생계급여지원', 'NNG'),
#  ('남성', 'NNG'),
#  ('신혼예비부부', 'NNG'),
#  ('고령노동인력', 'NNG'),
#  ('농업교육', 'NNG'),
#  ('글로벌인재', 'NNG'),
#  ('재활정보', 'NNG'),
#  ('누적포인트', 'NNG'),
#  ('관광객', 'NNG'),
#  ('심뇌혈관질환', 'NNG'),
#  ('만성질환', 'NNG'),
#  ('유통환경', 'NNG'),
#  ('소형하우스', 'NNG'),
#  ('비닐수거', 'NNG'),
#  ('한부모', 'NNG'),
#  ('따릉', 'NNG'),
#  ('공적연금', 'NNG'),
#  ('출산후', 'NNG'),
#  ('구강건강', 'NNG'),
#  ('유해동물', 'NNG'),
#  ('아이돌보미', 'NNG'),
#  ('농가경영', 'NNG'),
#  ('청각선별검사', 'NNG'),
#  ('건강지원센터', 'NNG'),
#  ('노인장기요양', 'NNG'),
#  ('구획어업', 'NNG'),
#  ('특수교육대상자', 'NNG'),
#  ('기관', 'NNG'),
#  ('청소년독서실', 'NNG'),
#  ('예방접종', 'NNG'),
#  ('예우지원', 'NNG'),
#  ('현황', 'NNG'),
#  ('김장비', 'NNG'),
#  ('격리치료', 'NNG'),
#  ('수유부', 'NNG'),
#  ('유아청소년', 'NNG'),
#  ('미취업자', 'NNG'),
#  ('독거노인', 'NNG'),
#  ('미취업청년', 'NNG'),
#  ('주차난', 'NNG'),
#  ('차량취득세', 'NNG'),
#  ('저소득주민', 'NNG'),
#  ('출산장려', 'NNG'),
#  ('화물자동차', 'NNG'),
#  ('학위증', 'NNG'),
#  ('물류단지', 'NNG'),
#  ('재산조회', 'NNG'),
#  ('방폐장', 'NNG'),
#  ('수련비', 'NNG'),
#  ('운영지원', 'NNG'),
#  ('경로당', 'NNG'),
#  ('배드민턴장', 'NNG'),
#  ('최저생활보장', 'NNG'),
#  ('보건실', 'NNG'),
#  ('월세자금보증', 'NNG'),
#  ('원예특용농업인', 'NNG'),
#  ('전통혼례', 'NNG'),
#  ('서울형', 'NNG'),
#  ('치매안심돌봄', 'NNG'),
#  ('가축전염병', 'NNG'),
#  ('생계의료수급가구', 'NNG'),
#  ('장애물', 'NNG'),
#  ('노후불량주택', 'NNG'),
#  ('미지급', 'NNG'),
#  ('과수농업인', 'NNG'),
#  ('돌봄지원', 'NNG'),
#  ('임실군립도서관', 'NNG'),
#  ('공공도서관', 'NNG'),
#  ('외국인주민', 'NNG'),
#  ('경기도형', 'NNG'),
#  ('교류도시', 'NNG'),
#  ('대기환경오염', 'NNG'),
#  ('상수도시설', 'NNG'),
#  ('경관농업인', 'NNG'),
#  ('생계급여수급대상자', 'NNG'),
#  ('금융지식', 'NNG'),
#  ('세탁차량', 'NNG'),
#  ('예방교육', 'NNG'),
#  ('출생아', 'NNG'),
#  ('폐렴구균', 'NNG'),
#  ('건강진단서', 'NNG'),
#  ('처우개선', 'NNG'),
#  ('사회보장', 'NNG'),
#  ('계란마킹', 'NNG'),
#  ('입주금', 'NNG'),
#  ('소득격차', 'NNG'),
#  ('농어촌빈집', 'NNG'),
#  ('제작', 'NNG'),
#  ('선별비', 'NNG'),
#  ('치유프로그램', 'NNG'),
#  ('재해복구비', 'NNG'),
#  ('상담서비스', 'NNG'),
#  ('사료구매자금', 'NNG'),
#  ('진로체험', 'NNG'),
#  ('가출청소년', 'NNG'),
#  ('농업경영지원', 'NNG'),
#  ('남성근로자', 'NNG'),
#  ('방과후', 'NNG'),
#  ('거래', 'NNG'),
#  ('심하지않은장애', 'NNG'),
#  ('학자금', 'NNG'),
#  ('위기청소년', 'NNG'),
#  ('지급금', 'NNG'),
#  ('축산시설', 'NNG'),
#  ('수질검사', 'NNG'),
#  ('위탁아동', 'NNG'),
#  ('종합보험', 'NNG'),
#  ('중증질환자', 'NNG'),
#  ('의료지원', 'NNG'),
#  ('돌봄체계', 'NNG'),
#  ('심리안정', 'NNG'),
#  ('도시철도요금', 'NNG'),
#  ('수학여행비', 'NNG'),
#  ('출산가정', 'NNG'),
#  ('주거급여', 'NNG'),
#  ('도시공원', 'NNG'),
#  ('산후조리원', 'NNG'),
#  ('생산시설지원', 'NNG'),
#  ('장애', 'NNG'),
#  ('문의', 'NNG'),
#  ('전쟁기념식', 'NNG'),
#  ('직업재활시설', 'NNG'),
#  ('비만아동', 'NNG'),
#  ('국민연금', 'NNG'),
#  ('보육교직원', 'NNG'),
#  ('수급권자', 'NNG'),
#  ('복지회관', 'NNG'),
#  ('소득계층', 'NNG'),
#  ('농축산업', 'NNG'),
#  ('재산세', 'NNG'),
#  ('무급휴직', 'NNG'),
#  ('이동기기', 'NNG'),
#  ('태아', 'NNG'),
#  ('예비신혼부부', 'NNG'),
#  ('복지후생금', 'NNG'),
#  ('부양가족생활보호비', 'NNG'),
#  ('예방백신', 'NNG'),
#  ('후속절차', 'NNG'),
#  ('의료봉사', 'NNG'),
#  ('영농교육', 'NNG'),
#  ('출산비', 'NNG'),
#  ('성인지', 'NNG'),
#  ('축산농가', 'NNG'),
#  ('볼링장', 'NNG'),
#  ('사회참여', 'NNG'),
#  ('임부', 'NNG'),
#  ('초음파진단기술', 'NNG'),
#  ('토종벌', 'NNG'),
#  ('재가통합', 'NNG'),
#  ('문화행사', 'NNG'),
#  ('재선충병', 'NNG'),
#  ('불공정거래', 'NNG'),
#  ('금융부담', 'NNG'),
#  ('생활체육', 'NNG'),
#  ('민간업', 'NNG'),
#  ('임대재산세', 'NNG'),
#  ('수송지원', 'NNG'),
#  ('에이즈', 'NNG'),
#  ('보호구역', 'NNG'),
#  ('부담금', 'NNG'),
#  ('장애연금', 'NNG'),
#  ('연구기관', 'NNG'),
#  ('노숙시설', 'NNG'),
#  ('기형아검사', 'NNG'),
#  ('한국어교실', 'NNG'),
#  ('고령사회', 'NNG'),
#  ('농업자녀', 'NNG'),
#  ('육성', 'NNG'),
#  ('융복합', 'NNG'),
#  ('수상레저', 'NNG'),
#  ('창의과학', 'NNG'),
#  ('무료주차장', 'NNG'),
#  ('알선', 'NNG'),
#  ('태양광발전기', 'NNG'),
#  ('희망복지지원단', 'NNG'),
#  ('법인', 'NNG'),
#  ('긴급복지사업', 'NNG'),
#  ('권익보호', 'NNG'),
#  ('농수축산물', 'NNG'),
#  ('시술비', 'NNG'),
#  ('고용우수기업', 'NNG'),
#  ('행정지원', 'NNG'),
#  ('보육교사', 'NNG'),
#  ('문화체험', 'NNG'),
#  ('간판개선', 'NNG'),
#  ('국가보훈대상자', 'NNG'),
#  ('도배장판', 'NNG'),
#  ('해상공동작업대', 'NNG'),
#  ('시립문수궁도장', 'NNG'),
#  ('유해야생동물', 'NNG'),
#  ('입시설명회', 'NNG'),
#  ('모유수유', 'NNG'),
#  ('도시가스배관망', 'NNG'),
#  ('세정술', 'NNG'),
#  ('돌봄서비스', 'NNG'),
#  ('환수금', 'NNG'),
#  ('영화관람지원', 'NNG'),
#  ('창조', 'NNG'),
#  ('도로명주소', 'NNG'),
#  ('재난기본소득', 'NNG'),
#  ('실버페스티벌', 'NNG'),
#  ('납부대행', 'NNG'),
#  ('변제금', 'NNG'),
#  ('2자녀', 'NNG'),
#  ('노인요양시설', 'NNG'),
#  ('장례비', 'NNG'),
#  ('헬스장', 'NNG'),
#  ('구인', 'NNG'),
#  ('재개장', 'NNG'),
#  ('여가생활', 'NNG'),
#  ('퇴거명령', 'NNG'),
#  ('알리미', 'NNG'),
#  ('산후조리비', 'NNG'),
#  ('포상금', 'NNG'),
#  ('레포츠센터', 'NNG'),
#  ('사회배려대상', 'NNG'),
#  ('재해지역민', 'NNG'),
#  ('강원형', 'NNG'),
#  ('여가선용', 'NNG'),
#  ('전입신고', 'NNG'),
#  ('도서대출서비스', 'NNG'),
#  ('병역명문가', 'NNG'),
#  ('심정지환자', 'NNG'),
#  ('국민내일카드', 'NNG'),
#  ('자동측정기기', 'NNG'),
#  ('노인복지서비스', 'NNG'),
#  ('노인장기요양보험료', 'NNG'),
#  ('학교폭력', 'NNG'),
#  ('양로원', 'NNG'),
#  ('법률상담', 'NNG'),
#  ('창업자금지원', 'NNG'),
#  ('자금난완화', 'NNG'),
#  ('농산물직거래', 'NNG'),
#  ('통계조사', 'NNG'),
#  ('취업박람회', 'NNG'),
#  ('오토캠핑장', 'NNG'),
#  ('재외국인', 'NNG'),
#  ('질환자', 'NNG'),
#  ('도박중독', 'NNG'),
#  ('스쿨존', 'NNG'),
#  ('예비맘', 'NNG'),
#  ('어선소유자', 'NNG'),
#  ('불소도포', 'NNG'),
#  ('시력 검진', 'NNG'),
#  ('행정정보', 'NNG'),
#  ('입원생활', 'NNG'),
#  ('고가양식장비', 'NNG'),
#  ('근무수당', 'NNG'),
#  ('알림', 'NNG'),
#  ('기초생활보장', 'NNG'),
#  ('정신보건', 'NNG'),
#  ('외국인', 'NNG'),
#  ('양육지원금', 'NNG'),
#  ('성평등', 'NNG'),
#  ('원예작물하우스', 'NNG'),
#  ('긴급돌봄', 'NNG'),
#  ('효문화', 'NNG'),
#  ('특수형태근로', 'NNG'),
#  ('교통규제', 'NNG'),
#  ('복지사각지대', 'NNG'),
#  ('농업인의날', 'NNG'),
#  ('동물등록제', 'NNG'),
#  ('영농도우미', 'NNG'),
#  ('접종비', 'NNG'),
#  ('공공후견비용', 'NNG'),
#  ('서비스기관', 'NNG'),
#  ('방문처리', 'NNG'),
#  ('농작물체험', 'NNG'),
#  ('수료증', 'NNG'),
#  ('가사방문', 'NNG'),
#  ('보호센터', 'NNG'),
#  ('방역비', 'NNG'),
#  ('농식품', 'NNG'),
#  ('노인봉사단체', 'NNG'),
#  ('사회복귀시설', 'NNG'),
#  ('하폐수처리', 'NNG'),
#  ('장애인재활', 'NNG'),
#  ('체험실', 'NNG'),
#  ('구군', 'NNG'),
#  ('기회보장', 'NNG'),
#  ('중증재가장애인', 'NNG'),
#  ('저체중아동', 'NNG'),
#  ('딸기무병보', 'NNG'),
#  ('한글교실', 'NNG'),
#  ('전통식품', 'NNG'),
#  ('다문화마을', 'NNG'),
#  ('양돈농가', 'NNG'),
#  ('외국인근로자', 'NNG'),
#  ('주민편익시설', 'NNG'),
#  ('무료급식서비스', 'NNG'),
#  ('국가정원', 'NNG'),
#  ('공동주택시설', 'NNG'),
#  ('교통안전실', 'NNG'),
#  ('뇌혈관질환', 'NNG'),
#  ('아동건강', 'NNG'),
#  ('지역고용', 'NNG'),
#  ('소년소녀', 'NNG'),
#  ('난치성', 'NNG'),
#  ('생산하우스', 'NNG'),
#  ('사회복지센터', 'NNG'),
#  ('영상전화', 'NNG'),
#  ('교육', 'NNG'),
#  ('따릉이', 'NNG'),
#  ('결혼적령기', 'NNG'),
#  ('자유무역협정', 'NNG'),
#  ('안마서비스', 'NNG'),
#  ('대처능력', 'NNG'),
#  ('복지제도', 'NNG'),
#  ('이자기간', 'NNG'),
#  ('복지수당', 'NNG'),
#  ('국민경제', 'NNG'),
#  ('경매사', 'NNG'),
#  ('소상인', 'NNG'),
#  ('동화나라', 'NNG'),
#  ('의료급여수급', 'NNG'),
#  ('설치비용', 'NNG'),
#  ('임산부철분지원', 'NNG'),
#  ('도로법', 'NNG'),
#  ('소년소녀가장', 'NNG'),
#  ('장애아', 'NNG'),
#  ('공공시설물', 'NNG'),
#  ('진로', 'NNG'),
#  ('금연구역', 'NNG'),
#  ('청소년', 'NNG'),
#  ('장난감대여센터', 'NNG'),
#  ('언어장벽', 'NNG'),
#  ('대산항', 'NNG'),
#  ('임신검사', 'NNG'),
#  ('차상위계층', 'NNG'),
#  ('교육훈련보조금', 'NNG'),
#  ('유해환경', 'NNG'),
#  ('공립도서관', 'NNG'),
#  ('범죄피해', 'NNG'),
#  ('공공자전거', 'NNG'),
#  ('장애인자동차', 'NNG'),
#  ('임업', 'NNG'),
#  ('영농폐기물', 'NNG'),
#  ('안전보행', 'NNG'),
#  ('전통시장', 'NNG'),
#  ('1박2일', 'NNG'),
#  ('생태농업단지', 'NNG'),
#  ('자원보존', 'NNG'),
#  ('보조기기', 'NNG'),
#  ('단체', 'NNG'),
#  ('장애영아반', 'NNG'),
#  ('전통음식', 'NNG'),
#  ('의약품비', 'NNG'),
#  ('정신장애인', 'NNG'),
#  ('육아보육서비스', 'NNG'),
#  ('안전지역', 'NNG'),
#  ('양극화', 'NNG'),
#  ('시립', 'NNG'),
#  ('민원처리', 'NNG'),
#  ('다자녀가구', 'NNG'),
#  ('농촌총각', 'NNG'),
#  ('플러스센터', 'NNG'),
#  ('감면대상', 'NNG'),
#  ('기업발굴', 'NNG'),
#  ('노숙쉼터', 'NNG'),
#  ('미아보호', 'NNG'),
#  ('초내열', 'NNG'),
#  ('당진항', 'NNG'),
#  ('행사비', 'NNG'),
#  ('정보지원', 'NNG'),
#  ('산모', 'NNG'),
#  ('유공자', 'NNG'),
#  ('상호대차서비스', 'NNG'),
#  ('암검진', 'NNG'),
#  ('인공달팽이관', 'NNG'),
#  ('무료급식소', 'NNG'),
#  ('정보통신보조기기', 'NNG'),
#  ('인플루엔자예방접종', 'NNG'),
#  ('익산시립예술단', 'NNG'),
#  ('보육서비스', 'NNG'),
#  ('구민회관', 'NNG'),
#  ('임산부건강검사', 'NNG'),
#  ('기초생활보장사업', 'NNG'),
#  ('의료급여', 'NNG'),
#  ('미용비', 'NNG'),
#  ('맞벌이가족', 'NNG'),
#  ('생계의료급여', 'NNG'),
#  ('문화강좌', 'NNG'),
#  ('귀농귀촌종합센터', 'NNG'),
#  ('미귀가자', 'NNG'),
#  ('농업지도자', 'NNG'),
#  ('의료생활', 'NNG'),
#  ('홍보관', 'NNG'),
#  ('농어업인', 'NNG'),
#  ('배려자', 'NNG'),
#  ('빈곤세대', 'NNG'),
#  ('가족문화센터', 'NNG'),
#  ('주민자치프로그램', 'NNG'),
#  ('소득수준', 'NNG'),
#  ('청각검사비', 'NNG'),
#  ('융자보조', 'NNG'),
#  ('국토교통기술사업', 'NNG'),
#  ('여권발급', 'NNG'),
#  ('중독', 'NNG'),
#  ('상수도요금', 'NNG'),
#  ('결혼이민자가족', 'NNG'),
#  ('학비경감', 'NNG'),
#  ('여성쉼터', 'NNG'),
#  ('방문재활서비스', 'NNG'),
#  ('약품비', 'NNG'),
#  ('주민센터', 'NNG'),
#  ('재활복지서비스', 'NNG'),
#  ('입소료', 'NNG'),
#  ('작업비', 'NNG'),
#  ...]

# %%
# 정상적으로 사용자 사전을 인식하는지 테스트
len(test), len(final_userdic), set([tag for _, tag in test])
# Out:
# (2507, 2507, {'NNG'})

# %%
def clean_text(text_raw):
    """
    문자열 전처리 함수.
    정규표현식을 사용해 한글/숫자/영어에 해당되지 않는 문자열을 제거
    """
    text_clean = re.sub("[^가-힣A-Za-z\\d\\s]", " ", text_raw).lower()
    return text_clean

def pos(text_raw):
    """
    형태소 분석기를 이용해 텍스트에서 명사 및 고유명사만 추출
    """
    text = clean_text(text_raw)
    # 형태소 분석기를 이용해 명사만 추출
    result = []
    for token, tag in komoran.pos(text):
        if tag == 'NNG' or tag == 'NNP':  # 명사 및 고유명사만 추출
            result.append(token)

    return " ".join(result)

# def prepro_tag(tag):
#     """
#     태그 데이터 전처리 함수
#         - 주어진 태그데이터를 하나의 문자열로 치환
#     """
#     return clean_text(" ".join(tag))

# %% [markdown]
# ### 서비스명 품사 태깅

# %%
# 품사 태깅 전, 단어 간 공백 처리

pat = ['북한\s?이탈\s?주민','새터\s?민',
       '민주\s?유공자','독립\s?유공자',
       '국가\s?유공자','특수\s?임무\s?유공자',
       '참전\s?유공자','518\s?민주화?\s?유공자',
       '518\s?유공자',
       '기초\s?생활\s?수급자','기초\s?생활\s?보장\s?수급자',
       '기초\s?생활\s?수급\s?가구','국민\s?기초\s?생활\s?대상자',
       '국민\s?기초\s?생활\s?수급자','기초\s?수급자',
       '기초\s?수급\s?대상자','국민\s?기초\s?생활\s?보장\s?수급자',
       '국민\s?기초\s?생활\s?수급자','기초\s?수급\s?가구',
       '기초\s?생활\s?보장\s?수급\s?가구','기초\s?생활\s?보급\s?수급자',
       '중증\s?장애인','경증\s?장애인',
       '청각\s?장애인','시각\s?장애인',
       '신장\s?장애인','발달\s?장애인',
       '지체\s?장애인','정신\s?장애인',
       '척수\s?장애인','지적\s?장애인',
       '자폐\s?장애인','장애\s?연금',
       '장애\s?정도\s?심한\s?장애인',
       '심한\s?장애','심하지\s?않은\s?장애',
       '다문화\s?가족?정?구?','한부모\s?가족?정?구?',
       '보훈\s?가정?족?구?','다자녀\s?가구?족?정?',
       '입양\s?가정?족?구?','조손\s?가정?족?구?',
       '교통\s?약자',
       '상수도\s?요금','수도\s?요금',
       '공영\s?주차장',
       '푸드\s?뱅크','푸드\s?마켓',
       '자살\s?위험군',
       '의료\s?급여','생계\s?급여','주거\s?급여','교육\s?급여',
       '실업\s?급여','퇴직\s?급여','생활\s?급여','보험\s?급여',
       '생계\s?급여','해산\s?급여','시설\s?급여','구직\s?급여',
       '요양\s?급여','장제\s?급여','재가\s?급여',
       '도로명\s?주소',
       '코로나\s?19',
       '뇌\s?병\s?변\s?장애인',
       '사회적\s?배려자','사회적\s?약자',
       '정보\s?소외\s?계층',
       '공공\s?도서관','공공\s?기관',
       '임대\s?주택','임대\s?아파트',
       '건강\s?검진']
       
repl =['북한이탈주민','북한이탈주민',
       '민주유공자','독립유공자',
       '국가유공자','특수임무유공자',
       '참전유공자','518민주유공자',
       '518민주유공자',
       '기초생활수급자','기초생활수급자',
       '기초생활수급자','기초생활수급자',
       '기초생활수급자','기초생활수급자',
       '기초생활수급자','기초생활수급자',
       '기초생활수급자','기초생활수급자',
       '기초생활수급자','기초생활수급자',
       '중증장애인','경증장애인',
       '청각장애인','시각장애인',
       '신장장애인','발달장애인',
       '지체장애인','정신장애인',
       '척수장애인','지적장애인',
       '자폐장애인','장애연금',
       '중증장애인',
       '중증장애','경증장애',
       '다문화가족','한부모가족',
       '보훈가족','다자녀가구',
       '입양가족','조손가족',
       '교통약자',
       '상수도요금','수도요금',
       '공영주차장',
       '푸드뱅크','푸드마켓',
       '자살위험군',
       '의료급여','생계급여','주거급여','교육급여',
       '실업급여','퇴직급여','생활급여','보험급여',
       '생계급여','해산급여','시설급여','구직급여',
       '요양급여','장제급여','재가급여',
       '도로명주소',
       '코로나19',
       '뇌병변장애인',
       '사회적약자','사회적약자',
       '정보소외계층',
       '공공도서관','공공기관',
       '임대주택','임대아파트',
       '건강검진']

# %%
list(zip(pat,repl))
# Out:
# [('북한\\s?이탈\\s?주민', '북한이탈주민'),
#  ('새터\\s?민', '북한이탈주민'),
#  ('민주\\s?유공자', '민주유공자'),
#  ('독립\\s?유공자', '독립유공자'),
#  ('국가\\s?유공자', '국가유공자'),
#  ('특수\\s?임무\\s?유공자', '특수임무유공자'),
#  ('참전\\s?유공자', '참전유공자'),
#  ('518\\s?민주화?\\s?유공자', '518민주유공자'),
#  ('518\\s?유공자', '518민주유공자'),
#  ('기초\\s?생활\\s?수급자', '기초생활수급자'),
#  ('기초\\s?생활\\s?보장\\s?수급자', '기초생활수급자'),
#  ('기초\\s?생활\\s?수급\\s?가구', '기초생활수급자'),
#  ('국민\\s?기초\\s?생활\\s?대상자', '기초생활수급자'),
#  ('국민\\s?기초\\s?생활\\s?수급자', '기초생활수급자'),
#  ('기초\\s?수급자', '기초생활수급자'),
#  ('기초\\s?수급\\s?대상자', '기초생활수급자'),
#  ('국민\\s?기초\\s?생활\\s?보장\\s?수급자', '기초생활수급자'),
#  ('국민\\s?기초\\s?생활\\s?수급자', '기초생활수급자'),
#  ('기초\\s?수급\\s?가구', '기초생활수급자'),
#  ('기초\\s?생활\\s?보장\\s?수급\\s?가구', '기초생활수급자'),
#  ('기초\\s?생활\\s?보급\\s?수급자', '기초생활수급자'),
#  ('중증\\s?장애인', '중증장애인'),
#  ('경증\\s?장애인', '경증장애인'),
#  ('청각\\s?장애인', '청각장애인'),
#  ('시각\\s?장애인', '시각장애인'),
#  ('신장\\s?장애인', '신장장애인'),
#  ('발달\\s?장애인', '발달장애인'),
#  ('지체\\s?장애인', '지체장애인'),
#  ('정신\\s?장애인', '정신장애인'),
#  ('척수\\s?장애인', '척수장애인'),
#  ('지적\\s?장애인', '지적장애인'),
#  ('자폐\\s?장애인', '자폐장애인'),
#  ('장애\\s?연금', '장애연금'),
#  ('장애\\s?정도\\s?심한\\s?장애인', '중증장애인'),
#  ('심한\\s?장애', '중증장애'),
#  ('심하지\\s?않은\\s?장애', '경증장애'),
#  ('다문화\\s?가족?정?구?', '다문화가족'),
#  ('한부모\\s?가족?정?구?', '한부모가족'),
#  ('보훈\\s?가정?족?구?', '보훈가족'),
#  ('다자녀\\s?가구?족?정?', '다자녀가구'),
#  ('입양\\s?가정?족?구?', '입양가족'),
#  ('조손\\s?가정?족?구?', '조손가족'),
#  ('교통\\s?약자', '교통약자'),
#  ('상수도\\s?요금', '상수도요금'),
#  ('수도\\s?요금', '수도요금'),
#  ('공영\\s?주차장', '공영주차장'),
#  ('푸드\\s?뱅크', '푸드뱅크'),
#  ('푸드\\s?마켓', '푸드마켓'),
#  ('자살\\s?위험군', '자살위험군'),
#  ('의료\\s?급여', '의료급여'),
#  ('생계\\s?급여', '생계급여'),
#  ('주거\\s?급여', '주거급여'),
#  ('교육\\s?급여', '교육급여'),
#  ('실업\\s?급여', '실업급여'),
#  ('퇴직\\s?급여', '퇴직급여'),
#  ('생활\\s?급여', '생활급여'),
#  ('보험\\s?급여', '보험급여'),
#  ('생계\\s?급여', '생계급여'),
#  ('해산\\s?급여', '해산급여'),
#  ('시설\\s?급여', '시설급여'),
#  ('구직\\s?급여', '구직급여'),
#  ('요양\\s?급여', '요양급여'),
#  ('장제\\s?급여', '장제급여'),
#  ('재가\\s?급여', '재가급여'),
#  ('도로명\\s?주소', '도로명주소'),
#  ('코로나\\s?19', '코로나19'),
#  ('뇌\\s?병\\s?변\\s?장애인', '뇌병변장애인'),
#  ('사회적\\s?배려자', '사회적약자'),
#  ('사회적\\s?약자', '사회적약자'),
#  ('정보\\s?소외\\s?계층', '정보소외계층'),
#  ('공공\\s?도서관', '공공도서관'),
#  ('공공\\s?기관', '공공기관'),
#  ('임대\\s?주택', '임대주택'),
#  ('임대\\s?아파트', '임대아파트'),
#  ('건강\\s?검진', '건강검진')]

# %%
def preprocess_word(text):
  result = text
  for pattern, replace in zip(pat, repl):
    result = re.sub(pattern, replace, result)
  return result

# %%
title_sub = title.apply(preprocess_word)

# %%
# print(preprocess_word('''
# 북한 이탈 주민,북한이탈 주민,북한 이탈주민
# 새터 민
# 국가 유공자,독립 유공자
# 민주 유공자,민주화 운동
# 기초 생활 수급자,기초생활 수급자,기초 생활수급자,기초생활보장 수급자,기초 생활 보장 수급자
# 기초생활보장 수급자
# 중증 장애인
# 청각 장애인
# 시각 장애인
# 신장 장애인
# 발달 장애인
# 다문화 가족, 한부모 가족, 보훈 가족
# 다문화 가정
# 교통 약자
# 상수도 요금, 수도 요금
# 공영 주차장
# 푸드 뱅크,푸드 마켓
# 자살 위험군
# 의료 급여, 생계 급여, 주거 급여, 교육 급여,실업 급여
# 도로명 주소
# 다자녀 가구
# 코로나 19
# 뇌 병 변 장애인
# 사회적 배려자
# 정보 소외계층
# 공공 도서관,공공 기관
# 임대 주택,임대 아파트
# 건강 검진'''))

# %%
title_n = title_sub.apply(pos)

# %% [markdown]
# ### 서비스 목적 품사 태깅

# %%
purpose_sub = purpose.apply(preprocess_word)

# %%
purpose_sub = purpose_sub.apply(lambda x:x.replace('\n','').replace('\t','').replace('\r','').replace('  ',' '))

# %%
purpose_n = purpose_sub.copy()
fail_lst = []

for i in purpose_sub.index:
  try:
    purpose_n.loc[i] = pos(purpose_sub.loc[i])
  except:
    fail_lst.append(i)
    fail_lst.append(purpose_sub.loc[i])

# %%
purpose.loc[30876]
# Out:
# '.'

# %%
fail_lst
# Out:
# [30876, '.']

# %%
purpose_n.loc[30876]=''

# %%
#title에 대해 명사 추출
title_n
# Out:
# 정책ID
# 1        유치원 유아 학비 지원 누리과정 운영
# 2                   근로 자녀 장려금
# 3                    월세 자금 보증
# 4              대한민국 운영자금 산업은행
# 5            친환경 에너지 절감 장비 보급
#                  ...
# 88482            피해 보전 직불금 지원
# 88483             이혼 위기 가족 지원
# 88484           여성 일 센터 운영 지원
# 88485              취학 아동 실명예방
# 88486        시흥 갯골 캠핑장 이용료 감면
# Name: 서비스명, Length: 88486, dtype: object

# %%
#purpose에 대해 명사 추출
purpose_n
# Out:
# 정책ID
# 1        누리과정 대상 어린이집 표준 보육 과정 유치원 교육 과정 통합 지원 대상 확대 부모...
# 2        근로자녀 장려 세제 저소득계층 빈곤 탈출 지원 사회안전망 확충 도입 근로 소득 사업...
# 3                                  저소득 월세자금보증 저소득 주거 안정 제고
# 4                                 코로나19 피해 중소 중견기업 지원 프로그램
# 5                   연근해 어업인 대상 노후기관 장비 설비 체 보급 안정 조업 기반 조성
#                                ...
# 88482    이행 수입 급증 가격 하락 피해 품목 생산자 가격 하락 일정 부분 피해 보전 직불금...
# 88483                        이혼 위기 가족 대상 가족 기능 회복 아동 복리 증진
# 88484    육아 가사 경력 단절 여성 대상 직업 상담 구인 구직 관리 직업 교육 인턴십 취업 ...
# 88485    취학 아동기 시력 검진 눈 건강관리 교육 시력 안 질환 조기 발견 치료 관리 아동 ...
# 88486                          시흥 갯골 캠핑장 이용 요금 할인 혜택 정보 제공
# Name: 서비스목적, Length: 88486, dtype: object

# %% [markdown]
# # 임베딩
#
# - 태그의 속성을 구체적인 벡터값으로 임베딩
# - 임베딩된 벡터는 태그(단어)의 언어적 맥락을 반영할 수 있어야 함
#     - Word2Vec 이용
#     - 코싸인 유사도를 바탕으로 평가

# %% [markdown]
# ## Word2Vec

# %%
# 하이퍼파라미터 정의

num_features = 128      # 임베딩 벡터 차원 수
min_word_count = 15     # 특정 단어의 최소 빈도수 (빈도가 적은 단어는 학습하지 않습니다!)
context = 5            # 컨텍스트 윈도우 크기 (양 옆으로 몇개의 단어를 참고할지) -> 정확히 확인
downsampling = 1e-3     # 다운샘플링 비율

# %%
# 학습 과정을 표시하기 위함
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# 명사태깅 전체 concat
noun = title_n + ' ' + purpose_n

# %%
# 사전컬럼에 대한 임베딩 모델 학습

# 모델 학습용 데이터 정의
texts = []
for ele in noun:
  texts.append(ele.split())

# 모델 학습
print("Training model...")
model = word2vec.Word2Vec(texts,
                          size=num_features,
                          min_count=min_word_count,
                          window=context,
                          sample=downsampling)

# 모델 저장
model.save("./data/{}features_{}minwords_{}context".format(num_features, min_word_count, context))
# Out:
# 2021-11-23 08:58:16,782 : INFO : collecting all words and their counts
# 2021-11-23 08:58:16,783 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-11-23 08:58:16,830 : INFO : PROGRESS: at sentence #10000, processed 198650 words, keeping 5929 word types
# 2021-11-23 08:58:16,881 : INFO : PROGRESS: at sentence #20000, processed 399700 words, keeping 7076 word types
# 2021-11-23 08:58:16,933 : INFO : PROGRESS: at sentence #30000, processed 603023 words, keeping 7794 word types
# Training model...
# 2021-11-23 08:58:16,983 : INFO : PROGRESS: at sentence #40000, processed 801154 words, keeping 8609 word types
# 2021-11-23 08:58:17,032 : INFO : PROGRESS: at sentence #50000, processed 994799 words, keeping 9383 word types
# 2021-11-23 08:58:17,079 : INFO : PROGRESS: at sentence #60000, processed 1190959 words, keeping 10074 word types
# 2021-11-23 08:58:17,129 : INFO : PROGRESS: at sentence #70000, processed 1394240 words, keeping 10557 word types
# 2021-11-23 08:58:17,181 : INFO : PROGRESS: at sentence #80000, processed 1598987 words, keeping 11042 word types
# 2021-11-23 08:58:17,228 : INFO : collected 13470 word types from a corpus of 1765827 raw words and 88486 sentences
# 2021-11-23 08:58:17,229 : INFO : Loading a fresh vocabulary
# 2021-11-23 08:58:17,253 : INFO : effective_min_count=15 retains 4684 unique words (34% of original 13470, drops 8786)
# 2021-11-23 08:58:17,254 : INFO : effective_min_count=15 leaves 1733406 word corpus (98% of original 1765827, drops 32421)
# 2021-11-23 08:58:17,274 : INFO : deleting the raw counts dictionary of 13470 items
# 2021-11-23 08:58:17,276 : INFO : sample=0.001 downsamples 58 most-common words
# 2021-11-23 08:58:17,279 : INFO : downsampling leaves estimated 1491273 word corpus (86.0% of prior 1733406)
# 2021-11-23 08:58:17,303 : INFO : estimated required memory for 4684 words and 128 dimensions: 7138416 bytes
# 2021-11-23 08:58:17,304 : INFO : resetting layer weights
# 2021-11-23 08:58:18,357 : INFO : training model with 3 workers on 4684 vocabulary and 128 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2021-11-23 08:58:19,366 : INFO : EPOCH 1 - PROGRESS: at 61.91% examples, 918688 words/s, in_qsize 6, out_qsize 0
# 2021-11-23 08:58:19,934 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-23 08:58:19,945 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-23 08:58:19,946 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-23 08:58:19,948 : INFO : EPOCH - 1 : training on 1765827 raw words (1490953 effective words) took 1.6s, 942622 effective words/s
# 2021-11-23 08:58:20,979 : INFO : EPOCH 2 - PROGRESS: at 63.02% examples, 915538 words/s, in_qsize 4, out_qsize 1
# 2021-11-23 08:58:21,540 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-23 08:58:21,545 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-23 08:58:21,551 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-23 08:58:21,552 : INFO : EPOCH - 2 : training on 1765827 raw words (1491224 effective words) took 1.6s, 934900 effective words/s
# 2021-11-23 08:58:22,567 : INFO : EPOCH 3 - PROGRESS: at 64.81% examples, 955774 words/s, in_qsize 5, out_qsize 0
# 2021-11-23 08:58:23,105 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-23 08:58:23,111 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-23 08:58:23,117 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-23 08:58:23,119 : INFO : EPOCH - 3 : training on 1765827 raw words (1491625 effective words) took 1.6s, 958205 effective words/s
# 2021-11-23 08:58:24,135 : INFO : EPOCH 4 - PROGRESS: at 63.08% examples, 928647 words/s, in_qsize 5, out_qsize 0
# 2021-11-23 08:58:24,701 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-23 08:58:24,708 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-23 08:58:24,711 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-23 08:58:24,713 : INFO : EPOCH - 4 : training on 1765827 raw words (1491267 effective words) took 1.6s, 940213 effective words/s
# 2021-11-23 08:58:25,725 : INFO : EPOCH 5 - PROGRESS: at 63.02% examples, 933951 words/s, in_qsize 5, out_qsize 0
# 2021-11-23 08:58:26,293 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-23 08:58:26,300 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-23 08:58:26,303 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-23 08:58:26,305 : INFO : EPOCH - 5 : training on 1765827 raw words (1492016 effective words) took 1.6s, 942956 effective words/s
# 2021-11-23 08:58:26,306 : INFO : training on a 8829135 raw words (7457085 effective words) took 7.9s, 938389 effective words/s
# 2021-11-23 08:58:26,307 : INFO : saving Word2Vec object under ./data/128features_15minwords_5context, separately None
# 2021-11-23 08:58:26,309 : INFO : not storing attribute vectors_norm
# 2021-11-23 08:58:26,311 : INFO : not storing attribute cum_table
# 2021-11-23 08:58:26,389 : INFO : saved ./data/128features_15minwords_5context

# %% [markdown]
# ## 임베딩 벡터 생성

# %%
def get_embedding_vector(words, model=model, num_features=num_features):
  # 중복 단어 삭제
  words = list(set(words))

  # 출력 벡터 초기화
  feature_vector = np.zeros(num_features, dtype=np.float32)

  num_words = 0
  index2word_set = set(model.wv.index2word)    # 어휘사전

  # 어휘사전에 포함된 단어 벡터들의 평균값을 해당 텍스트의 임베딩 벡터로 사용
  for w in words:
    if w in index2word_set:
      num_words += 1
      feature_vector = np.add(feature_vector, model[w])

  feature_vector = np.divide(feature_vector, num_words)
  return feature_vector.reshape(1, -1)

# %%
len(model.wv.index2word)
# Out:
# 4684

# %%
# model.wv.index2word

# %%
word1 = ["고엽제"]
word2 = ["유공자"]

example1_vec = get_embedding_vector(word1)
example2_vec = get_embedding_vector(word2)

print(np.isnan(example1_vec).sum())
print(np.isnan(example1_vec).sum())

cosine_similarity(example1_vec, example2_vec)
# Out:
# 0
# 0
# array([[0.5024376]], dtype=float32)

# %%
# cosine_similarity( get_embedding_vector(['노인', '독거']), get_embedding_vector(["유치원", "청소년"]) )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app
# array([[0.20358789]], dtype=float32)

# %% [markdown]
# # 적용

# %%
concat = (content + ' ' + subject).apply(lambda x:x.replace('\n',' ').replace('\t',' ').replace('\r',' '))

# %%
# 특수 단어(예:민주 유공자->민주 유공자) 등 처리
concat = concat.apply(preprocess_word)

# %%
concat_n = concat.apply(pos)

# %%
concat_n.to_csv("./data/지원대상_내용_noun_with_userdic.csv",encoding='CP949',index=False)

# %%
title_n.to_csv("./data/서비스명_noun_with_userdic.csv",encoding='CP949',index=False)
purpose_n.to_csv("./data/서비스목적_noun_with_userdic.csv",encoding='CP949',index=False)

# %% [markdown]
# # 환경설정 후 이것만 돌려주세요!

# %%
# 미리 학습한 모델 로드
word2vec_model = Word2Vec.load("./data/128features_15minwords_5context")

# 하이퍼파라미터 정의

num_features = 128      # 임베딩 벡터 차원 수
min_word_count = 15     # 특정 단어의 최소 빈도수 (빈도가 적은 단어는 학습하지 않습니다!)
context = 5            # 컨텍스트 윈도우 크기 (양 옆으로 몇개의 단어를 참고할지) -> 정확히 확인
downsampling = 1e-3     # 다운샘플링 비율  

def get_embedding_vector(words, model=word2vec_model, num_features=num_features):
  # 중복 단어 삭제
  words = list(set(words))

  # 출력 벡터 초기화
  feature_vector = np.zeros(num_features, dtype=np.float32)

  num_words = 0
  index2word_set = set(model.wv.index2word)    # 어휘사전

  # 어휘사전에 포함된 단어 벡터들의 평균값을 해당 텍스트의 임베딩 벡터로 사용
  for w in words:
    if w in index2word_set:
      num_words += 1
      feature_vector = np.add(feature_vector, model[w])

  feature_vector = np.divide(feature_vector, num_words)
  return feature_vector.reshape(1, -1)

# %%
# 지원대상+지원내용 명사
concat_n = pd.read_csv("./data/지원대상_내용_noun_with_userdic.csv",encoding='CP949')
concat_n.index = range(1,88487)

# 서비스명 명사
title_n = pd.read_csv("./data/서비스명_noun_with_userdic.csv",encoding='CP949')
title_n.index = range(1,88487)

# 서비스목적 명사
purpose_n = pd.read_csv("./data/서비스목적_noun_with_userdic.csv",encoding='CP949')
purpose_n.index = range(1,88487)

# %%
# 결측이 있는 행은 제외
title_n = title_n[title_n.서비스명.isna()==False]
purpose_n = purpose_n[purpose_n.서비스목적.isna()==False]

# %%
concat_n = concat_n['0']
title_n = title_n['서비스명']
purpose_n = purpose_n['서비스목적']

# %%
# 불용어
worksheet = gc.open('vector_dic_final').sheet1
rows = worksheet.get_all_values()

stop_df = pd.DataFrame.from_records(rows[1:], columns = rows[0])
stopwords = stop_df[stop_df['삭제할 단어']=='0'].단어.unique().tolist()

# %%
start = 1 # 정책ID 시작
end = 10000 # 정책ID 끝

# %%
# 참조컬럼이 서비스명이면 title_n을, 서비스목적이면 purpose_n으로 바꿔주세요.
IDs = sorted(list(set(range(start, end+1)) & set(title_n.index)))

title_result = pd.DataFrame(columns=['id','word','score'])

for id in tqdm(IDs):
  #참조컬럼: title_n(서비스명), purpose_n(서비스목적)에 따라 변경
  label = [x for x in title_n.loc[id].split(' ') if len(x)>1] 

  for word in set(concat_n.loc[id].split(' ')):
    # 한 글자 명사 및 불용어 제외
    if len(word)>1 and word not in stopwords:
      try:
        score= cosine_similarity(get_embedding_vector(word),
                                get_embedding_vector(label)) 
        title_result = title_result.append({'id':id,'word':word,'score':score}, ignore_index=True)                   
      except: 
        continue
        # print(id, word, np.isnan(get_embedding_vector(word)).sum())

  # 정책 id가 2000의 배수일때 마다 백업이 됨
  # 백업 주기를 조정하고 싶을 시 아래 2000을 다른 숫자로 바꾸기
  # if id % 2000 == 0: 
    
    # 경로 이름을 본인 이름으로 변경해주세요.
    # result.to_csv('./신형/result_{}_{}.csv'.format(start,id), 
    #               index=False, encoding='CP949')

title_result.score = title_result.score.map(lambda x:x[0][0])
title_result.sort_values(by=['id','score'], ascending=False, inplace=True)

title_result.to_csv('./result/result_{}_{}_title.csv'.format(start,end))
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 17.35it/s]

# %%
# 참조컬럼이 서비스명이면 title_n을, 서비스목적이면 purpose_n으로 바꿔주세요.
IDs = sorted(list(set(range(start, end+1)) & set(purpose_n.index)))

purpose_result = pd.DataFrame(columns=['id','word','score'])

for id in tqdm(IDs):
  #참조컬럼: title_n(서비스명), purpose_n(서비스목적)에 따라 변경
  label = [x for x in purpose_n.loc[id].split(' ') if len(x)>1] 

  for word in set(concat_n.loc[id].split(' ')):
    # 한 글자 명사 및 불용어 제외
    if len(word)>1 and word not in stopwords:
      try:
        score= cosine_similarity(get_embedding_vector(word),
                                get_embedding_vector(label)) 
        purpose_result = purpose_result.append({'id':id,'word':word,'score':score}, ignore_index=True)                   
      except: 
        continue
        # print(id, word, np.isnan(get_embedding_vector(word)).sum())

  # 정책 id가 2000의 배수일때 마다 백업이 됨
  # 백업 주기를 조정하고 싶을 시 아래 2000을 다른 숫자로 바꾸기
  # if id % 2000 == 0: 
    
    # 경로 이름을 본인 이름으로 변경해주세요.
    # result.to_csv('./신형/result_{}_{}_purpose.csv'.format(start,id), 
    #               index=False, encoding='CP949')

purpose_result.score = purpose_result.score.map(lambda x:x[0][0])
purpose_result.sort_values(by=['id','score'], ascending=False, inplace=True)

purpose_result.to_csv('./result/result_{}_{}_purpose.csv'.format(start,end))
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 16.98it/s]

# %%
total = pd.DataFrame(columns=['id','title','purpose'])

for id in tqdm(IDs):
  total = total.append({'id':id,
                        'title':title_result[title_result.id==id].head(5).word.tolist(),
                        'purpose':purpose_result[purpose_result.id==id].head(5).word.tolist(),},
                       ignore_index=True)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 237.28it/s]

# %%
total['title'] = total['title'].apply(lambda x: ','.join(x))
total['purpose'] = total['purpose'].apply(lambda x: ','.join(x))

# %%
total.to_csv('./result/추출키워드_test.csv', encoding='CP949',index=False)
